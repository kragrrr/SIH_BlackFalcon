# %%
# !python3.9 -m venv myvenv

# %%
# !source myvenv/bin/activate

# %%
# !python -m pip install --upgrade pip
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.9.6 torch-2.0.1 CPU (Apple M1 Pro)
# Setup complete ✅ (10 CPUs, 32.0 GB RAM, 641.5/926.4 GB disk)

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/Users/krish/Development/TIH/Tank_Detection_1-2/data.yaml epochs=50 imgsz=640 device='mps'
# Out:
# New https://pypi.org/project/ultralytics/8.0.183 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.181 🚀 Python-3.9.6 torch-2.0.1 MPS (Apple M1 Pro)
# ...

# %%
# !yolo task=detect mode=predict model=/Users/krish/Development/TIH/runs/detect/train/weights/best.pt source='https://www.youtube.com/watch?v=v4inbgmbUD8&t=5s' conf=0.99 show=True
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.9.6 torch-2.0.1 CPU (Apple M1 Pro)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
#
# 1/1: https://www.youtube.com/watch?v=v4inbgmbUD8&t=5s... Success ✅ (8630 frames of shape 1920x1080 at 25.00 FPS)
#
# 0: 384x640 2 0s, 133.3ms
# 0: 384x640 2 0s, 128.4ms
# 0: 384x640 1 0, 122.3ms
# 0: 384x640 (no detections), 118.9ms
# 0: 384x640 2 0s, 119.8ms
# 0: 384x640 2 0s, 165.2ms
# 0: 384x640 2 0s, 122.2ms
# 0: 384x640 (no detections), 125.3ms
# 0: 384x640 (no detections), 117.6ms
# 0: 384x640 1 0, 117.4ms
# 0: 384x640 2 0s, 119.5ms
# 0: 384x640 (no detections), 120.7ms
# 0: 384x640 1 0, 124.3ms
# 0: 384x640 2 0s, 124.0ms
# 0: 384x640 (no detections), 120.6ms
# 0: 384x640 1 0, 117.1ms
# 0: 384x640 1 0, 109.2ms
# 0: 384x640 (no detections), 117.9ms
# 0: 384x640 (no detections), 127.6ms
# 0: 384x640 1 0, 123.8ms
# 0: 384x640 (no detections), 116.6ms
# 0: 384x640 1 0, 116.3ms
# 0: 384x640 3 0s, 119.7ms
# 0: 384x640 2 0s, 110.8ms
# ...
